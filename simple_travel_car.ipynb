# %%
import pyhop
from math import sqrt, pow

def distance(c1, c2):
    x=pow(c1['X']-c2['X'],2)
    y=pow(c1['Y']-c2['Y'],2)
    return sqrt(x+y)

def select_new_city(state,y):  #evaluation function
    x=state.location_car
    best=5000 #big int
    for c in state.connection.keys():
        if c not in state.path and c in state.connection[x]:
            g=state.cost
            h=distance(state.coordinates[c],state.coordinates[y])
            if g+h<best:
                best_city=c
                best=g+h
    return best_city

def travel_op(state,y):
    x=state.location
    if y in state.connection[x]:
        state.location = y
        state.path.append(y)
        state.cost += distance(state.coordinates[x],state.coordinates[y])
        return state
    else: return False
    
def load_car_op(state):
    x=state.location
    y=state.location_car
    if x==y:
        state.location='coche'
        return state
    return False

def unload_car_op(state):
    x=state.location
    y=state.location_car
    if x=='coche':
        state.location=y
        return state
    return False

pyhop.declare_operators(travel_op,load_car_op,unload_car_op)
print('')
pyhop.print_operators()

def travel_m(state,goal):
    x=state.location_car
    y=goal.final
    if x!=y:
        z=select_new_city(state,y)
        g=pyhop.Goal('g')
        g.final=y
        return [('travel_op',z), ('travel_to_city',g)]
    return False

def already_there(state,goal):
    x=state.location_car
    y=goal.final
    if x==y:
        return []
    return False

pyhop.declare_methods('travel_to_city',travel_m, already_there)



def travel_by_car(state,goal):
    x=state.location
    y=goal.final
    if x!=y:
        return [('load_car_op',), ('travel_to_city',goal), ('unload_car_op',)]
    return False

pyhop.declare_methods('travel',travel_by_car)
print('')
pyhop.print_methods()

#INITIAL STATE

state1 = pyhop.State('state1')
state1.coordinates = {'Huelva':{'X':25,'Y':275}, 'Cadiz':{'X':200,'Y':50}, 'Sevilla':{'X':250,'Y':325},
                      'Cordoba':{'X':475,'Y':450}, 'Malaga':{'X':550,'Y':100}, 'Jaen':{'X':750,'Y':425},
                      'Granada':{'X':800,'Y':250}, 'Almeria':{'X':1000,'Y':150}}
state1.connection = {'Huelva':{'Sevilla'}, 'Sevilla':{'Cadiz','Huelva','Cordoba','Malaga'},
                     'Cadiz':{'Sevilla','Malaga'}, 'Cordoba':{'Sevilla','Malaga','Jaen'},
                     'Malaga':{'Cadiz','Huelva','Cordoba','Sevilla','Granada','Almeria'},
                     'Jaen':{'Cordoba','Granada'},'Granada':{'Jaen','Malaga','Almeria'},
                     'Almeria':{'Granada','Malaga'}}
state1.location = 'Huelva'
state1.location_car = 'Huelva'
state1.path = ['Huelva']
state1.cost = 0

#GOAL
goal1 = pyhop.Goal('goal1')
goal1.final = 'Almeria'

print('- If verbose=3, Pyhop also prints the intermediate states:')

result=pyhop.pyhop(state1,[('travel',goal1)],verbose=3)

print(result)
# Out:
# OPERATORS: load_car_op, unload_car_op, travel_op
#
# TASK:         METHODS:
# travel_to_citytravel_m, already_there
# load_car_op   load
# unload_car_op unload
# travel        travel_by_car
# - If verbose=3, Pyhop also prints the intermediate states:
# ** pyhop, verbose=3: **
#    state = state1
#    tasks = [('travel', <pyhop.Goal object at 0x000002C49C518CF8>)]
# depth 0 tasks [('travel', <pyhop.Goal object at 0x000002C49C518CF8>)]
# depth 0 method instance ('travel', <pyhop.Goal object at 0x000002C49C518CF8>)
# depth 0 new tasks: [('load_car_op',), ('travel_to_city', <pyhop.Goal object at 0x000002C49C518CF8>), ('unload_car_op',)]
# depth 1 tasks [('load_car_op',), ('travel_to_city', <pyhop.Goal object at 0x000002C49C518CF8>), ('unload_car_op',)]
# depth 1 action ('load_car_op',)
# depth 1 new state:
#     state1.coordinates = {'Cordoba': {'X': 475, 'Y': 450}, 'Jaen': {'X': 750, 'Y': 425}, 'Sevilla': {'X': 250, 'Y': 325}, 'Granada': {'X': 800, 'Y': 250}, 'Huelva': {'X': 25, 'Y': 275}, 'Almeria': {'X': 1000, 'Y': 150}, 'Cadiz': {'X': 200, 'Y': 50}, 'Malaga': {'X': 550, 'Y': 100}}
#     state1.location_car = Huelva
#     state1.connection = {'Cordoba': {'Jaen', 'Sevilla', 'Malaga'}, 'Jaen': {'Cordoba', 'Granada'}, 'Sevilla': {'Cordoba', 'Huelva', 'Cadiz', 'Malaga'}, 'Granada': {'Jaen', 'Almeria', 'Malaga'}, 'Huelva': {'Sevilla'}, 'Almeria': {'Malaga', 'Granada'}, 'Cadiz': {'Sevilla', 'Malaga'}, 'Malaga': {'Sevilla', 'Granada', 'Huelva', 'Almeria', 'Cordoba', 'Cadiz'}}
#     state1.location = coche
#     state1.path = ['Huelva']
#     state1.cost = 0
# depth 2 tasks [('travel_to_city', <pyhop.Goal object at 0x000002C49C518CF8>), ('unload_car_op',)]
# depth 2 method instance ('travel_to_city', <pyhop.Goal object at 0x000002C49C518CF8>)
# depth 2 new tasks: [('travel_op', 'Sevilla'), ('travel_to_city', <pyhop.Goal object at 0x000002C49C50EDA0>)]
# depth 3 tasks [('travel_op', 'Sevilla'), ('travel_to_city', <pyhop.Goal object at 0x000002C49C50EDA0>), ('unload_car_op',)]
# depth 3 action ('travel_op', 'Sevilla')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-f3ce20fd3e5c> in <module>()
#     102 print('- If verbose=3, Pyhop also prints the intermediate states:')
#     103
# --> 104 result=pyhop.pyhop(state1,[('travel',goal1)],verbose=3)
#     105
#     106 print(result)
#
# C:\Users\Denas\Documents\python scripts\Sistemas Inteligentes\pyhop.py in pyhop(state, tasks, verbose)
#     198     """
#     199     if verbose>0: print('** pyhop, verbose={}: **\n   state = {}\n   tasks = {}'.format(verbose, state.__name__, tasks))
# --> 200     result = seek_plan(state,tasks,[],0,verbose)
#     201     if verbose>0: print('** result =',result,'\n')
#     202     return result
#
# C:\Users\Denas\Documents\python scripts\Sistemas Inteligentes\pyhop.py in seek_plan(state, tasks, plan, depth, verbose)
#     234                 print('depth {} new tasks: {}'.format(depth,subtasks))
#     235             if subtasks != False:
# --> 236                 solution = seek_plan(state,subtasks+tasks[1:],plan,depth+1,verbose)
#     237                 if solution != False:
#     238                     return solution
#
# C:\Users\Denas\Documents\python scripts\Sistemas Inteligentes\pyhop.py in seek_plan(state, tasks, plan, depth, verbose)
#     222             print_state(newstate)
#     223         if newstate:
# --> 224             solution = seek_plan(newstate,tasks[1:],plan+[task1],depth+1,verbose)
#     225             if solution != False:
#     226                 return solution
#
# C:\Users\Denas\Documents\python scripts\Sistemas Inteligentes\pyhop.py in seek_plan(state, tasks, plan, depth, verbose)
#     234                 print('depth {} new tasks: {}'.format(depth,subtasks))
#     235             if subtasks != False:
# --> 236                 solution = seek_plan(state,subtasks+tasks[1:],plan,depth+1,verbose)
#     237                 if solution != False:
#     238                     return solution
#
# C:\Users\Denas\Documents\python scripts\Sistemas Inteligentes\pyhop.py in seek_plan(state, tasks, plan, depth, verbose)
#     217         if verbose>2: print('depth {} action {}'.format(depth,task1))
#     218         operator = operators[task1[0]]
# --> 219         newstate = operator(copy.deepcopy(state),*task1[1:])
#     220         if verbose>2:
#     221             print('depth {} new state:'.format(depth))
#
# <ipython-input-4-f3ce20fd3e5c> in travel_op(state, y)
#      21 def travel_op(state,y):
#      22     x=state.location
# ---> 23     if y in state.connection[x]:
#      24         state.location = y
#      25         state.path.append(y)
#
# KeyError: 'coche'
