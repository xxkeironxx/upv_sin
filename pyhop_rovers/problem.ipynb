# %%
import pyhop
import rovers_methods
import rovers_tasks

state1=pyhop.State('state1')

state1.at={'r0':'w3'}
state1.at_lander='w0'
state1.empty={'r0store':True}
state1.calibrated={'r0':{'c0':False}}
state1.at_soil_sample={'w0','w2','w3'}
state1.at_rock_sample={'w1','w2','w3'}
state1.have_rock_analysis={'r0':[]}
state1.have_soil_analysis={'r0':[]}
state1.have_image={'r0':[]}
state1.communicated_soil_data=[]
state1.communicated_rock_data=[]
state1.communicated_image_data=[]
state1.crossed={'r0':['w3']}

#Static info
state1.can_traverse={'r0':[['w0','w3'],['w1','w3'],['w1','w2'],['w2','w0'],['w3','w0'],['w3','w1'],['w2','w1'],['w0','w2']]}
state1.equipped_for_soil_analysis={'r0'}
state1.equipped_for_rock_analysis={'r0'}
state1.equipped_for_imaging={'r0'}
state1.supports={'r0':{'c0':{'colour','high-res'}}}
state1.calibration_target={'c0':'o1'}
state1.on_board={'r0':{'c0'}}
state1.visible={'w0':{'w1','w2','w3'}, 'w1':{'w0','w2','w3'}, 'w2':{'w0','w1','w3'}, 'w3':{'w0','w1','w2'}}
state1.visible_from={'o1':{'w0','w1','w2','w3'}}
state1.store_of={'r0':'r0store'}
state1.rovers=['r0']

#GOAL
pyhop.print_methods()
pyhop.print_operators()
#pyhop.pyhop(state1, [('go_to_waypoint','r0','w2')], verbose=3)
#pyhop.pyhop(state1, [('communicate_soil_data','r0','w2')], verbose=3)
#pyhop.pyhop(state1, [('communicate_rock_data','r0','w3')], verbose=3)
pyhop.pyhop(state1, [('communicate_image_data','r0','o1','high-res')], verbose=3)
# Out:
# TASK:         METHODS:
# communicate_soil_datacommunicate_soil_data_m
# communicate_rock_datacommunicate_rock_data_m
# communicate_image_datacommunicate_image_data_m
# go_to_waypointgo_to_waypoint_m
# OPERATORS: sample_soil, already_there, communicate_image_data_to_lander, calibrate, take_image, drop, communicate_soil_data_to_lander, navigate, sample_rock, communicate_rock_data_to_lander
# ** pyhop, verbose=3: **
#    state = state1
#    tasks = [('communicate_image_data', 'r0', 'o1', 'high-res')]
# depth 0 tasks [('communicate_image_data', 'r0', 'o1', 'high-res')]
# depth 0 method instance ('communicate_image_data', 'r0', 'o1', 'high-res')
# depth 0 new tasks: [('calibrate', 'r0', ['c0'], 'o1'), ('take_image', 'r0', ['c0'], 'o1', 'high-res'), ('communicate_image_data_to_lander', 'r0', 'o1', 'high-res')]
# depth 1 tasks [('calibrate', 'r0', ['c0'], 'o1'), ('take_image', 'r0', ['c0'], 'o1', 'high-res'), ('communicate_image_data_to_lander', 'r0', 'o1', 'high-res')]
# depth 1 action ('calibrate', 'r0', ['c0'], 'o1')
# depth 1 new state:
#     state1.at_lander = w0
#     state1.calibration_target = {'c0': 'o1'}
#     state1.communicated_rock_data = []
#     state1.at = {'r0': 'w3'}
#     state1.visible = {'w0': {'w3', 'w2', 'w1'}, 'w3': {'w0', 'w2', 'w1'}, 'w2': {'w0', 'w3', 'w1'}, 'w1': {'w0', 'w3', 'w2'}}
#     state1.can_traverse = {'r0': [['w0', 'w3'], ['w1', 'w3'], ['w1', 'w2'], ['w2', 'w0'], ['w3', 'w0'], ['w3', 'w1'], ['w2', 'w1'], ['w0', 'w2']]}
#     state1.communicated_image_data = []
#     state1.equipped_for_rock_analysis = {'r0'}
#     state1.communicated_soil_data = []
#     state1.on_board = {'r0': {'c0'}}
#     state1.at_soil_sample = {'w0', 'w3', 'w2'}
#     state1.rovers = ['r0']
#     state1.have_image = {'r0': []}
#     state1.have_soil_analysis = {'r0': []}
#     state1.visible_from = {'o1': {'w0', 'w3', 'w2', 'w1'}}
#     state1.equipped_for_soil_analysis = {'r0'}
#     state1.supports = {'r0': {'c0': {'colour', 'high-res'}}}
#     state1.calibrated = {'r0': {'c0': True}}
#     state1.crossed = {'r0': ['w3']}
#     state1.store_of = {'r0': 'r0store'}
#     state1.at_rock_sample = {'w3', 'w2', 'w1'}
#     state1.equipped_for_imaging = {'r0'}
#     state1.empty = {'r0store': True}
#     state1.have_rock_analysis = {'r0': []}
# depth 2 tasks [('take_image', 'r0', ['c0'], 'o1', 'high-res'), ('communicate_image_data_to_lander', 'r0', 'o1', 'high-res')]
# depth 2 action ('take_image', 'r0', ['c0'], 'o1', 'high-res')
# depth 2 new state:
#     state1.at_lander = w0
#     state1.calibration_target = {'c0': 'o1'}
#     state1.communicated_rock_data = []
#     state1.at = {'r0': 'w3'}
#     state1.visible = {'w0': {'w3', 'w2', 'w1'}, 'w3': {'w0', 'w2', 'w1'}, 'w2': {'w0', 'w3', 'w1'}, 'w1': {'w0', 'w3', 'w2'}}
#     state1.can_traverse = {'r0': [['w0', 'w3'], ['w1', 'w3'], ['w1', 'w2'], ['w2', 'w0'], ['w3', 'w0'], ['w3', 'w1'], ['w2', 'w1'], ['w0', 'w2']]}
#     state1.communicated_image_data = []
#     state1.equipped_for_rock_analysis = {'r0'}
#     state1.communicated_soil_data = []
#     state1.on_board = {'r0': {'c0'}}
#     state1.at_soil_sample = {'w0', 'w3', 'w2'}
#     state1.rovers = ['r0']
#     state1.have_image = {'r0': ['o1_r0w3_c0_high-res']}
#     state1.have_soil_analysis = {'r0': []}
#     state1.visible_from = {'o1': {'w0', 'w3', 'w2', 'w1'}}
#     state1.equipped_for_soil_analysis = {'r0'}
#     state1.supports = {'r0': {'c0': {'colour', 'high-res'}}}
#     state1.calibrated = {'r0': {'c0': False}}
#     state1.crossed = {'r0': ['w3']}
#     state1.store_of = {'r0': 'r0store'}
#     state1.at_rock_sample = {'w3', 'w2', 'w1'}
#     state1.equipped_for_imaging = {'r0'}
#     state1.empty = {'r0store': True}
#     state1.have_rock_analysis = {'r0': []}
# depth 3 tasks [('communicate_image_data_to_lander', 'r0', 'o1', 'high-res')]
# depth 3 action ('communicate_image_data_to_lander', 'r0', 'o1', 'high-res')
# depth 3 new state:
#     state1.at_lander = w0
#     state1.calibration_target = {'c0': 'o1'}
#     state1.communicated_rock_data = []
#     state1.at = {'r0': 'w3'}
#     state1.visible = {'w0': {'w3', 'w2', 'w1'}, 'w3': {'w0', 'w2', 'w1'}, 'w2': {'w0', 'w3', 'w1'}, 'w1': {'w0', 'w3', 'w2'}}
#     state1.can_traverse = {'r0': [['w0', 'w3'], ['w1', 'w3'], ['w1', 'w2'], ['w2', 'w0'], ['w3', 'w0'], ['w3', 'w1'], ['w2', 'w1'], ['w0', 'w2']]}
#     state1.communicated_image_data = [['o1_r0w3_c0_high-res']]
#     state1.equipped_for_rock_analysis = {'r0'}
#     state1.communicated_soil_data = []
#     state1.on_board = {'r0': {'c0'}}
#     state1.at_soil_sample = {'w0', 'w3', 'w2'}
#     state1.rovers = ['r0']
#     state1.have_image = {'r0': ['o1_r0w3_c0_high-res']}
#     state1.have_soil_analysis = {'r0': []}
#     state1.visible_from = {'o1': {'w0', 'w3', 'w2', 'w1'}}
#     state1.equipped_for_soil_analysis = {'r0'}
#     state1.supports = {'r0': {'c0': {'colour', 'high-res'}}}
#     state1.calibrated = {'r0': {'c0': False}}
#     state1.crossed = {'r0': ['w3']}
#     state1.store_of = {'r0': 'r0store'}
#     state1.at_rock_sample = {'w3', 'w2', 'w1'}
#     state1.equipped_for_imaging = {'r0'}
#     state1.empty = {'r0store': True}
#     state1.have_rock_analysis = {'r0': []}
# depth 4 tasks []
# depth 4 returns plan [('calibrate', 'r0', ['c0'], 'o1'), ('take_image', 'r0', ['c0'], 'o1', 'high-res'), ('communicate_image_data_to_lander', 'r0', 'o1', 'high-res')]
# ** result = [('calibrate', 'r0', ['c0'], 'o1'), ('take_image', 'r0', ['c0'], 'o1', 'high-res'), ('communicate_image_data_to_lander', 'r0', 'o1', 'high-res')]
# [('calibrate', 'r0', ['c0'], 'o1'),
#  ('take_image', 'r0', ['c0'], 'o1', 'high-res'),
#  ('communicate_image_data_to_lander', 'r0', 'o1', 'high-res')]
